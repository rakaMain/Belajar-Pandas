# %%
import pandas as pd

# %%
mie = pd.read_csv('./dataset/penjualan_mie.csv')

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     20
# 1  Selasa        mie ayam       49     15
# 2    Rabu        mie ayam       45     15
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.loc[[0, 1, 5]]
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     20
# 1  Selasa        mie ayam       49     15
# 5   Sabtu        mie baso       55     12

# %%
mie.loc[0:]
# Out:
#       hari        tipe_mie  terjual  harga
# 0    Senin  mie bangladesh       49     20
# 1   Selasa        mie ayam       49     15
# 2     Rabu        mie ayam       45     15
# 3    Kamis       mie sedap       56     10
# 4    Jumat        mie baso       52     12
# 5    Sabtu        mie baso       55     12
# 6   Minggu  mie bangladesh       45     20
# 7    Senin  mie bangladesh       56     20
# 8   Selasa  mie bangladesh       53     20
# 9     Rabu        mie ayam       58     15
# 10   Kamis  mie bangladesh       40     20
# 11   Jumat       mie sedap       53     10
# 12   Sabtu        mie baso       51     12
# 13  Minggu  mie bangladesh       52     20
# 14   Senin       mie sedap       42     10
# 15  Selasa  mie bangladesh       54     20
# 16    Rabu  mie bangladesh       49     20
# 17   Kamis       mie sedap       41     10
# 18   Jumat  mie bangladesh       55     20
# 19   Sabtu  mie bangladesh       48     20
# 20  Minggu        mie baso       53     12
# ...

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     20
# 1  Selasa        mie ayam       49     15
# 2    Rabu        mie ayam       45     15
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.loc[0:3, ['tipe_mie', 'harga']]
# Out:
#          tipe_mie  harga
# 0  mie bangladesh     20
# 1        mie ayam     15
# 2        mie ayam     15
# 3       mie sedap     10

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     20
# 1  Selasa        mie ayam       49     15
# 2    Rabu        mie ayam       45     15
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.loc[0, 'harga'] = 30

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     30
# 1  Selasa        mie ayam       49     15
# 2    Rabu        mie ayam       45     15
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.loc[mie['tipe_mie'] == 'mie ayam', 'harga'] = 30

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     30
# 1  Selasa        mie ayam       49     30
# 2    Rabu        mie ayam       45     30
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.iloc[0:4 ,[2, 3]]
# Out:
#    terjual  harga
# 0       49     30
# 1       49     30
# 2       45     30
# 3       56     10

# %%
mie.head()
# Out:
#      hari        tipe_mie  terjual  harga
# 0   Senin  mie bangladesh       49     30
# 1  Selasa        mie ayam       49     30
# 2    Rabu        mie ayam       45     30
# 3   Kamis       mie sedap       56     10
# 4   Jumat        mie baso       52     12

# %%
mie.loc[0, ['hari','terjual']]
# Out:
# hari       Senin
# terjual       49
# Name: 0, dtype: object

# %%
mie_indexed = mie.set_index('hari')   # DataFrame baru, index = kolom 'hari'

# %%
mie.set_index('hari', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8884\2871449234.py in ?()
# ----> 1 mie.set_index('hari', inplace=True)
#
# ~\Desktop\belajar-pandas\venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6125                     if not found:
#    6126                         missing.append(col)
#    6127
#    6128         if missing:
# -> 6129             raise KeyError(f"None of {missing} are in the columns")
#    6130
#    6131         if inplace:
#    6132             frame = self
#
# KeyError: "None of ['hari'] are in the columns"

# %%
mie.head()
# Out:
#               tipe_mie  terjual  harga
# hari
# Senin   mie bangladesh       49     30
# Selasa        mie ayam       49     30
# Rabu          mie ayam       45     30
# Kamis        mie sedap       56     10
# Jumat         mie baso       52     12
