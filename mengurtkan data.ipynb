# %%
import pandas as pd

# %%
df_orang = pd.read_csv('./dataset/data_orang.csv')

# %%
df_orang.head()
# Out:
#              nama     provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0  Anwar Setiawan       Banten      Cilegon    1982-05-04           165
# 1   Fajar Wahyudi  Jawa Tengah        Tegal    1973-11-25           187
# 2   Agus Prasetya   Jawa Barat       Bekasi    1980-06-08           182
# 3      Eka Widodo   Jawa Barat      Cirebon    1988-10-26           164
# 4     Xavier Arif  DKI Jakarta      Jakarta    2004-01-15           160
#
#    berat_badan
# 0           59
# 1           72
# 2           83
# 3           73
# 4           89

# %%
df_orang.sort_values('tinggi_badan', ascending=False).head()
# Out:
#               nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 10       Fajar Nur    Jawa Tengah     Magelang    1990-05-04           190
# 13       Gita Hadi    Jawa Tengah     Salatiga    1982-02-09           190
# 93     Hendra Arif    Jawa Tengah        Tegal    1991-09-27           190
# 144  Niko Prasetya     Jawa Timur       Malang    1981-11-13           190
# 120      Rudi Arif  DI Yogyakarta   Yogyakarta    1995-07-25           189
#
#      berat_badan
# 10            98
# 13            89
# 93            60
# 144           82
# 120           87

# %%
df_orang.sort_values(['tinggi_badan', 'berat_badan'], ascending=False)
# Out:
#               nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 10       Fajar Nur    Jawa Tengah     Magelang    1990-05-04           190
# 13       Gita Hadi    Jawa Tengah     Salatiga    1982-02-09           190
# 144  Niko Prasetya     Jawa Timur       Malang    1981-11-13           190
# 93     Hendra Arif    Jawa Tengah        Tegal    1991-09-27           190
# 120      Rudi Arif  DI Yogyakarta   Yogyakarta    1995-07-25           189
# ..             ...            ...          ...           ...           ...
# 61    Agus Wahyudi     Jawa Barat        Depok    1982-05-31           152
# 33     Budi Widodo     Jawa Barat      Bandung    1985-03-02           151
# 102  Indah Santoso    Jawa Tengah        Tegal    1993-12-17           151
# 107     Anwar Arif         Banten      Cilegon    1971-10-22           151
# 85       Lina Arif     Jawa Timur       Malang    1976-08-11           151
#
#      berat_badan
# 10            98
# 13            89
# ...

# %%
df_orang.sort_values(['tinggi_badan', 'berat_badan'], ascending=[True, False])
# Out:
#               nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 33     Budi Widodo     Jawa Barat      Bandung    1985-03-02           151
# 102  Indah Santoso    Jawa Tengah        Tegal    1993-12-17           151
# 107     Anwar Arif         Banten      Cilegon    1971-10-22           151
# 85       Lina Arif     Jawa Timur       Malang    1976-08-11           151
# 65   Rudi Setiawan  DI Yogyakarta   Yogyakarta    1986-05-11           152
# ..             ...            ...          ...           ...           ...
# 120      Rudi Arif  DI Yogyakarta   Yogyakarta    1995-07-25           189
# 10       Fajar Nur    Jawa Tengah     Magelang    1990-05-04           190
# 13       Gita Hadi    Jawa Tengah     Salatiga    1982-02-09           190
# 144  Niko Prasetya     Jawa Timur       Malang    1981-11-13           190
# 93     Hendra Arif    Jawa Tengah        Tegal    1991-09-27           190
#
#      berat_badan
# 33            82
# 102           70
# ...
