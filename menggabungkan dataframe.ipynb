# %%
import pandas as pd

# %%
df1 = pd.read_csv('./dataset/data_orang.csv')

# %%
df2 = pd.read_csv('./dataset/data_orang_tambahan.csv')

# %%
df1.merge(df2, how='inner', on=['nama', 'tempat_lahir']).head()
# Out:
#               nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0    Fajar Wahyudi    Jawa Tengah        Tegal    1973-11-25           187
# 1       Eka Widodo     Jawa Barat      Cirebon    1988-10-26           164
# 2      Xavier Arif    DKI Jakarta      Jakarta    2004-01-15           160
# 3      Xavier Arif    DKI Jakarta      Jakarta    2004-01-15           160
# 4  Sinta Ramadhani  DI Yogyakarta   Yogyakarta    1979-08-29           171
#
#    berat_badan   pekerjaan       status
# 0           72  Freelancer        Nikah
# 1           73   Pramusaji        Nikah
# 2           89     Teknisi  Belum nikah
# 3           89  Freelancer        Nikah
# 4           51  Programmer  Belum nikah

# %%
df1.merge(df2, how='left')
# Out:
#                nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0    Anwar Setiawan         Banten      Cilegon    1982-05-04           165
# 1     Fajar Wahyudi    Jawa Tengah        Tegal    1973-11-25           187
# 2     Agus Prasetya     Jawa Barat       Bekasi    1980-06-08           182
# 3        Eka Widodo     Jawa Barat      Cirebon    1988-10-26           164
# 4       Xavier Arif    DKI Jakarta      Jakarta    2004-01-15           160
# ..              ...            ...          ...           ...           ...
# 162       Bella Nur         Banten       Serang    1994-06-06           164
# 163  Hendra Yuliana    Jawa Tengah    Surakarta    1973-03-15           153
# 164       Oki Putra     Jawa Timur       Madiun    1982-12-12           178
# 165     Sinta Putra  DI Yogyakarta   Yogyakarta    1982-03-19           182
# 166  Teguh Prasetya  DI Yogyakarta   Yogyakarta    1989-05-19           170
#
#      berat_badan   pekerjaan       status
# ...

# %%
df1.merge(df2, how='right')
# Out:
#                 nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0      Fajar Wahyudi    Jawa Tengah        Tegal    1973-11-25           187
# 1         Eka Widodo     Jawa Barat      Cirebon    1988-10-26           164
# 2        Xavier Arif    DKI Jakarta      Jakarta    2004-01-15           160
# 3        Xavier Arif    DKI Jakarta      Jakarta    1997-06-25           182
# 4    Sinta Ramadhani  DI Yogyakarta   Yogyakarta    1979-08-29           171
# ..               ...            ...          ...           ...           ...
# 129  Yulia Ramadhani    DKI Jakarta      Jakarta    1980-05-20           168
# 130    Niko Prasetya     Jawa Timur       Malang    1981-11-13           190
# 131        Bella Nur         Banten       Serang    1994-06-06           164
# 132        Oki Putra     Jawa Timur       Madiun    1982-12-12           178
# 133      Sinta Putra  DI Yogyakarta   Yogyakarta    1982-03-19           182
#
#      berat_badan   pekerjaan       status
# ...

# %%
df1.merge(df2, how='outer').head()
# Out:
#              nama    provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0       Agus Hadi  Jawa Barat      Cirebon    1995-04-04           156
# 1   Agus Prasetya  Jawa Barat       Bekasi    1980-06-08           182
# 2  Agus Ramadhani  Jawa Barat       Bekasi    1996-01-17           166
# 3    Agus Wahyudi  Jawa Barat       Bekasi    2004-09-04           168
# 4    Agus Wahyudi  Jawa Barat        Depok    1982-05-31           152
#
#    berat_badan        pekerjaan       status
# 0           49             Guru  Belum nikah
# 1           83              NaN          NaN
# 2           47       Freelancer  Belum nikah
# 3           50             Guru        Nikah
# 4           45  Karyawan Swasta  Belum nikah

# %%
df1.merge(df2, how='cross').head()
# Out:
#            nama_x provinsi tempat_lahir_x tanggal_lahir  tinggi_badan  \
# 0  Anwar Setiawan   Banten        Cilegon    1982-05-04           165
# 1  Anwar Setiawan   Banten        Cilegon    1982-05-04           165
# 2  Anwar Setiawan   Banten        Cilegon    1982-05-04           165
# 3  Anwar Setiawan   Banten        Cilegon    1982-05-04           165
# 4  Anwar Setiawan   Banten        Cilegon    1982-05-04           165
#
#    berat_badan           nama_y tempat_lahir_y   pekerjaan       status
# 0           59    Fajar Wahyudi          Tegal  Freelancer        Nikah
# 1           59       Eka Widodo        Cirebon   Pramusaji        Nikah
# 2           59      Xavier Arif        Jakarta     Teknisi  Belum nikah
# 3           59  Sinta Ramadhani     Yogyakarta  Programmer  Belum nikah
# 4           59    Dewi Prasetya          Bogor     Perawat        Nikah

# %%
pd.concat([df1, df2], axis=0, join='inner', ignore_index=False)
# Out:
#                 nama tempat_lahir
# 0     Anwar Setiawan      Cilegon
# 1      Fajar Wahyudi        Tegal
# 2      Agus Prasetya       Bekasi
# 3         Eka Widodo      Cirebon
# 4        Xavier Arif      Jakarta
# ..               ...          ...
# 107  Yulia Ramadhani      Jakarta
# 108    Niko Prasetya       Malang
# 109        Bella Nur       Serang
# 110        Oki Putra       Madiun
# 111      Sinta Putra   Yogyakarta
#
# [262 rows x 2 columns]

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                nama       provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# 0    Anwar Setiawan         Banten      Cilegon    1982-05-04           165
# 1     Fajar Wahyudi    Jawa Tengah        Tegal    1973-11-25           187
# 2     Agus Prasetya     Jawa Barat       Bekasi    1980-06-08           182
# 3        Eka Widodo     Jawa Barat      Cirebon    1988-10-26           164
# 4       Xavier Arif    DKI Jakarta      Jakarta    2004-01-15           160
# ..              ...            ...          ...           ...           ...
# 145       Bella Nur         Banten       Serang    1994-06-06           164
# 146  Hendra Yuliana    Jawa Tengah    Surakarta    1973-03-15           153
# 147       Oki Putra     Jawa Timur       Madiun    1982-12-12           178
# 148     Sinta Putra  DI Yogyakarta   Yogyakarta    1982-03-19           182
# 149  Teguh Prasetya  DI Yogyakarta   Yogyakarta    1989-05-19           170
#
# ...

# %%
pd.concat([df1, df2], keys=['a','b'])
# Out:
#                   nama     provinsi tempat_lahir tanggal_lahir  tinggi_badan  \
# a 0     Anwar Setiawan       Banten      Cilegon    1982-05-04         165.0
#   1      Fajar Wahyudi  Jawa Tengah        Tegal    1973-11-25         187.0
#   2      Agus Prasetya   Jawa Barat       Bekasi    1980-06-08         182.0
#   3         Eka Widodo   Jawa Barat      Cirebon    1988-10-26         164.0
#   4        Xavier Arif  DKI Jakarta      Jakarta    2004-01-15         160.0
# ...                ...          ...          ...           ...           ...
# b 107  Yulia Ramadhani          NaN      Jakarta           NaN           NaN
#   108    Niko Prasetya          NaN       Malang           NaN           NaN
#   109        Bella Nur          NaN       Serang           NaN           NaN
#   110        Oki Putra          NaN       Madiun           NaN           NaN
#   111      Sinta Putra          NaN   Yogyakarta           NaN           NaN
#
#        berat_badan   pekerjaan       status
# ...

# %%
df1.append(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10024\3062608662.py in ?()
# ----> 1 df1.append(df2)
#
# ~\Desktop\belajar-pandas\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
